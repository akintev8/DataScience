# %% [markdown]
# # Загрузка данных

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import pandas as pd 
df = pd.read_csv("https://raw.githubusercontent.com/luiseduardogfranca/students-performance/master/StudentsPerformance.csv") 
print(df.head()) 
print(df.info())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# ...

# %% [markdown]
# # Базовое исследование

# %%
print(df.shape)
print(df.columns) 
print(df.dtypes)
print(df.isnull().sum())
# Out:
# (1000, 8)
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # Простая статистика

# %%
print("Math:", (df["math score"].mean())) 
print("Reading:", df["reading score"].mean()) 
print("Writing:", df["writing score"].mean()) 
print("Math(max):", df["math score"].max(),"Math(min):", df["math score"].min()) 
print("Reading(max):", df["reading score"].max(),"Reading(min):", df["reading score"].min()) 
print("Writing(max):", df["writing score"].max(),"Writing(min):", df["writing score"].min()) 
print(df.groupby("gender")["math score"].mean()) 
print(df.groupby("gender")["reading score"].mean()) 
print(df.groupby("gender")["writing score"].mean())
# Out:
# Math: 66.089
# Reading: 69.169
# Writing: 68.054
# Math(max): 100 Math(min): 0
# Reading(max): 100 Reading(min): 17
# Writing(max): 100 Writing(min): 10
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64
# gender
# female    72.608108
# male      65.473029
# Name: reading score, dtype: float64
# gender
# female    72.467181
# male      63.311203
# Name: writing score, dtype: float64

# %% [markdown]
# # Распределение оценок по каждому предмету

# %%
sns.histplot(df["math score"], kde=True) 
plt.title("Распределение оценок по математике") 
plt.show() 
sns.histplot(df["reading score"], kde=True) 
plt.title("Распределение оценок по чтению") 
plt.show() 
sns.histplot(df["writing score"], kde=True) 
plt.title("Распределение оценок по письму") 
plt.show()

# %% [markdown]
# # Сравнение по полу

# %%
sns.boxplot(x="gender", y="math score", data=df) 
plt.title("Сравнение результатов по математике между полами") 
plt.show() 
sns.boxplot(x="gender", y="writing score", data=df) 
plt.title("Сравнение результатов по письму между полами") 
plt.show() 
sns.boxplot(x="gender", y="reading score", data=df) 
plt.title("Сравнение результатов по чтению между полами") 
plt.show()

# %% [markdown]
# # Влияние образования родителей

# %%
plt.figure(figsize=(10,5)) 
sns.barplot(x="parental level of education", y="math score", data=df) 
plt.title("Средний балл по математике в зависимости от образования родителей") 
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# # Влияние подготовки к тесту

# %%
sns.boxplot(x="test preparation course", y="math score", data=df) 
plt.title("Подготовка к тесту и результаты по математике") 
plt.show() 
sns.boxplot(x="test preparation course", y="reading score", data=df) 
plt.title("Подготовка к тесту и результаты по чтению") 
plt.show() 
sns.boxplot(x="test preparation course", y="writing score", data=df) 
plt.title("Подготовка к тесту и результаты по письму") 
plt.show()

# %% [markdown]
# # Корреляции

# %%
sns.heatmap(df[["math score", "reading score", "writing score"]].corr(), annot=True, cmap="Blues") 
plt.title("Корреляция между предметами") 
plt.show()
